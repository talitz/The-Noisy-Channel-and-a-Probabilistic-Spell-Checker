# %% [markdown]
# Assignment 1 Tests

# %%
import ex1
text = 'A cat sat on the mat. A fat cat sat on the mat. A rat sat on the mat. The rat sat on the cat. A bat spat on the rat that sat on the cat on the mat.'
nt = ex1.normalize_text(text) #lower casing, padding punctuation with white spaces
print(nt)
lm = ex1.Ngram_Language_Model(n=3, chars=False)
lm.build_model(nt)  #*
print(lm.get_model()) #*
#t = lm.generate(context = 'a cat',n=30)
#for e in [t, 'a cat sat on the mat','the rat sat on the cat' ]: #*
#    print('%s | %.3f' %(e, lm.evaluate(e)))
# Out:
# a cat sat on the mat . a fat cat sat on the mat . a rat sat on the mat . the rat sat on the cat . a bat spat on the rat that sat on the cat on the mat .
# defaultdict(<class 'int'>, {'a cat sat': 1, 'cat sat on': 2, 'sat on the': 5, 'on the mat': 4, 'the mat .': 4, 'mat . a': 2, '. a fat': 1, 'a fat cat': 1, 'fat cat sat': 1, '. a rat': 1, 'a rat sat': 1, 'rat sat on': 2, 'mat . the': 1, '. the rat': 1, 'the rat sat': 1, 'on the cat': 2, 'the cat .': 1, 'cat . a': 1, '. a bat': 1, 'a bat spat': 1, 'bat spat on': 1, 'spat on the': 1, 'on the rat': 1, 'the rat that': 1, 'rat that sat': 1, 'that sat on': 1, 'the cat on': 1, 'cat on the': 1})

# %% [markdown]
# Assignment 2 Tests

# %%
import ex2_api
from ex2_api import get_all_correct_words

sc = ex2_api.Spell_Checker(lm)
commmon_errors_dict = sc.learn_error_distribution("commmon_errors.tsv")
print(commmon_errors_dict)
print(get_all_correct_words("commmon_errors.tsv"))
# Out:
# -------------------
# Error = abandonned
# Correction = abandoned
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = bandonned
# current char = b
# first part = a
# second part = andonned
# current char = a
# first part = ab
# second part = ndonned
# current char = n
# first part = aba
# second part = donned
# current char = d
# first part = aban
# second part = onned
# current char = o
# first part = aband
# second part = nned
# current char = n
# first part = abando
# second part = ned
# added tupple = ('n', 'o')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = aberation
# Correction = aberration
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = e
# corr[i] = e
# err[i] = r
# corr[i] = r
# err[i] = a
# corr[i] = r
# --
# err[0:i] = aber
# corr[i] = r
# err[i+1:] = tion
# aberration
# --
# added tupple = ('r', 'r')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = abilityes
# Correction = abilities
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = i
# corr[i] = i
# err[i] = l
# corr[i] = l
# err[i] = i
# corr[i] = i
# err[i] = t
# corr[i] = t
# err[i] = y
# corr[i] = i
# added tupple = ('i', 't')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = abilties
# Correction = abilities
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = i
# corr[i] = i
# err[i] = l
# corr[i] = l
# err[i] = t
# corr[i] = i
# --
# err[0:i] = abil
# corr[i] = i
# err[i+1:] = ies
# abilities
# --
# added tupple = ('i', 'l')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = abilty
# Correction = ability
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = i
# corr[i] = i
# err[i] = l
# corr[i] = l
# err[i] = t
# corr[i] = i
# --
# err[0:i] = abil
# corr[i] = i
# err[i+1:] = y
# ability
# --
# added tupple = ('i', 'l')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = abondon
# Correction = abandon
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = o
# corr[i] = a
# added tupple = ('a', 'b')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = abbout
# Correction = about
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = bbout
# current char = b
# first part = a
# second part = bout
# added tupple = ('b', 'a')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = abotu
# Correction = about
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = o
# corr[i] = o
# err[i] = t
# corr[i] = u
# -------------------
# -------------------
# Error = abouta
# Correction = about a
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = o
# corr[i] = o
# err[i] = u
# corr[i] = u
# err[i] = t
# corr[i] = t
# err[i] = a
# corr[i] =
# --
# err[0:i] = about
# corr[i] =
# err[i+1:] =
# about a
# --
# added tupple = (' ', 't')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = aboutit
# Correction = about it
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = o
# corr[i] = o
# err[i] = u
# corr[i] = u
# err[i] = t
# corr[i] = t
# err[i] = i
# corr[i] =
# --
# err[0:i] = about
# corr[i] =
# err[i+1:] = t
# about it
# --
# added tupple = (' ', 't')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = aboutthe
# Correction = about the
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = o
# corr[i] = o
# err[i] = u
# corr[i] = u
# err[i] = t
# corr[i] = t
# err[i] = t
# corr[i] =
# --
# err[0:i] = about
# corr[i] =
# err[i+1:] = he
# about the
# --
# added tupple = (' ', 't')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = abscence
# Correction = absence
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = bscence
# current char = b
# first part = a
# second part = scence
# current char = s
# first part = ab
# second part = cence
# current char = c
# first part = abs
# second part = ence
# added tupple = ('c', 's')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = abondoned
# Correction = abandoned
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = o
# corr[i] = a
# added tupple = ('a', 'b')
# substitution_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = abondoning
# Correction = abandoning
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = o
# corr[i] = a
# added tupple = ('a', 'b')
# substitution_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = abondons
# Correction = abandons
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = o
# corr[i] = a
# added tupple = ('a', 'b')
# substitution_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = aborigene
# Correction = aborigine
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = o
# corr[i] = o
# err[i] = r
# corr[i] = r
# err[i] = i
# corr[i] = i
# err[i] = g
# corr[i] = g
# err[i] = e
# corr[i] = i
# added tupple = ('i', 'g')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accesories
# Correction = accessories
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = e
# corr[i] = e
# err[i] = s
# corr[i] = s
# err[i] = o
# corr[i] = s
# --
# err[0:i] = acces
# corr[i] = s
# err[i+1:] = ries
# accessories
# --
# added tupple = ('s', 's')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accidant
# Correction = accident
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = i
# corr[i] = i
# err[i] = d
# corr[i] = d
# err[i] = a
# corr[i] = e
# added tupple = ('e', 'd')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = abreviate
# Correction = abbreviate
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = r
# corr[i] = b
# --
# err[0:i] = ab
# corr[i] = b
# err[i+1:] = eviate
# abbreviate
# --
# added tupple = ('b', 'b')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = abreviated
# Correction = abbreviated
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = r
# corr[i] = b
# --
# err[0:i] = ab
# corr[i] = b
# err[i+1:] = eviated
# abbreviated
# --
# added tupple = ('b', 'b')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = abreviation
# Correction = abbreviation
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = r
# corr[i] = b
# --
# err[0:i] = ab
# corr[i] = b
# err[i+1:] = eviation
# abbreviation
# --
# added tupple = ('b', 'b')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = abritrary
# Correction = arbitrary
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = r
# added tupple = ('br', 'rb')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = absail
# Correction = abseil
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = s
# corr[i] = s
# err[i] = a
# corr[i] = e
# added tupple = ('e', 's')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = absailing
# Correction = abseiling
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = s
# corr[i] = s
# err[i] = a
# corr[i] = e
# added tupple = ('e', 's')
# substitution_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = absense
# Correction = absence
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = s
# corr[i] = s
# err[i] = e
# corr[i] = e
# err[i] = n
# corr[i] = n
# err[i] = s
# corr[i] = c
# added tupple = ('c', 'n')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = absolutly
# Correction = absolutely
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = s
# corr[i] = s
# err[i] = o
# corr[i] = o
# err[i] = l
# corr[i] = l
# err[i] = u
# corr[i] = u
# err[i] = t
# corr[i] = t
# err[i] = l
# corr[i] = e
# --
# err[0:i] = absolut
# corr[i] = e
# err[i+1:] = y
# absolutely
# --
# added tupple = ('e', 't')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = absorbtion
# Correction = absorption
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = s
# corr[i] = s
# err[i] = o
# corr[i] = o
# err[i] = r
# corr[i] = r
# err[i] = b
# corr[i] = p
# added tupple = ('p', 'r')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = abudance
# Correction = abundance
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = u
# corr[i] = u
# err[i] = d
# corr[i] = n
# --
# err[0:i] = abu
# corr[i] = n
# err[i+1:] = ance
# abundance
# --
# added tupple = ('n', 'u')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = abundancies
# Correction = abundances
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = bundancies
# current char = b
# first part = a
# second part = undancies
# current char = u
# first part = ab
# second part = ndancies
# current char = n
# first part = abu
# second part = dancies
# current char = d
# first part = abun
# second part = ancies
# current char = a
# first part = abund
# second part = ncies
# current char = n
# first part = abunda
# second part = cies
# current char = c
# first part = abundan
# second part = ies
# current char = i
# first part = abundanc
# second part = es
# added tupple = ('i', 'c')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = abundunt
# Correction = abundant
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = b
# corr[i] = b
# err[i] = u
# corr[i] = u
# err[i] = n
# corr[i] = n
# err[i] = d
# corr[i] = d
# err[i] = u
# corr[i] = a
# added tupple = ('a', 'd')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = abutts
# Correction = abuts
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = butts
# current char = b
# first part = a
# second part = utts
# current char = u
# first part = ab
# second part = tts
# current char = t
# first part = abu
# second part = ts
# added tupple = ('t', 'u')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = acadamy
# Correction = academy
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = a
# corr[i] = e
# added tupple = ('e', 'd')
# substitution_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acadmic
# Correction = academic
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = m
# corr[i] = e
# --
# err[0:i] = acad
# corr[i] = e
# err[i+1:] = ic
# academic
# --
# added tupple = ('e', 'd')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accademic
# Correction = academic
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = ccademic
# current char = c
# first part = a
# second part = cademic
# added tupple = ('c', 'a')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accademy
# Correction = academy
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = ccademy
# current char = c
# first part = a
# second part = cademy
# added tupple = ('c', 'a')
# deletion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acccused
# Correction = accused
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = cccused
# current char = c
# first part = a
# second part = ccused
# added tupple = ('c', 'a')
# deletion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = accelleration
# Correction = acceleration
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = ccelleration
# current char = c
# first part = a
# second part = celleration
# current char = c
# first part = ac
# second part = elleration
# current char = e
# first part = acc
# second part = lleration
# current char = l
# first part = acce
# second part = leration
# added tupple = ('l', 'e')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accension
# Correction = accession
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = e
# corr[i] = e
# err[i] = n
# corr[i] = s
# added tupple = ('s', 'e')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = acceptence
# Correction = acceptance
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = e
# corr[i] = e
# err[i] = p
# corr[i] = p
# err[i] = t
# corr[i] = t
# err[i] = e
# corr[i] = a
# added tupple = ('a', 't')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = acceptible
# Correction = acceptable
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = e
# corr[i] = e
# err[i] = p
# corr[i] = p
# err[i] = t
# corr[i] = t
# err[i] = i
# corr[i] = a
# added tupple = ('a', 't')
# substitution_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = accessable
# Correction = accessible
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = e
# corr[i] = e
# err[i] = s
# corr[i] = s
# err[i] = s
# corr[i] = s
# err[i] = a
# corr[i] = i
# added tupple = ('i', 's')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = acident
# Correction = accident
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = i
# corr[i] = c
# --
# err[0:i] = ac
# corr[i] = c
# err[i+1:] = dent
# accident
# --
# added tupple = ('c', 'c')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accidentaly
# Correction = accidentally
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = i
# corr[i] = i
# err[i] = d
# corr[i] = d
# err[i] = e
# corr[i] = e
# err[i] = n
# corr[i] = n
# err[i] = t
# corr[i] = t
# err[i] = a
# corr[i] = a
# err[i] = l
# corr[i] = l
# err[i] = y
# corr[i] = l
# --
# err[0:i] = accidental
# corr[i] = l
# err[i+1:] =
# accidentally
# --
# added tupple = ('l', 'l')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = acclimitization
# Correction = acclimatization
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = l
# corr[i] = l
# err[i] = i
# corr[i] = i
# err[i] = m
# corr[i] = m
# err[i] = i
# corr[i] = a
# added tupple = ('a', 'm')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accomodate
# Correction = accommodate
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = o
# err[i] = m
# corr[i] = m
# err[i] = o
# corr[i] = m
# --
# err[0:i] = accom
# corr[i] = m
# err[i+1:] = date
# accommodate
# --
# added tupple = ('m', 'm')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accomodated
# Correction = accommodated
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = o
# err[i] = m
# corr[i] = m
# err[i] = o
# corr[i] = m
# --
# err[0:i] = accom
# corr[i] = m
# err[i+1:] = dated
# accommodated
# --
# added tupple = ('m', 'm')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = accomodates
# Correction = accommodates
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = o
# err[i] = m
# corr[i] = m
# err[i] = o
# corr[i] = m
# --
# err[0:i] = accom
# corr[i] = m
# err[i+1:] = dates
# accommodates
# --
# added tupple = ('m', 'm')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = accomodating
# Correction = accommodating
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = o
# err[i] = m
# corr[i] = m
# err[i] = o
# corr[i] = m
# --
# err[0:i] = accom
# corr[i] = m
# err[i+1:] = dating
# accommodating
# --
# added tupple = ('m', 'm')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = accomodation
# Correction = accommodation
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = o
# err[i] = m
# corr[i] = m
# err[i] = o
# corr[i] = m
# --
# err[0:i] = accom
# corr[i] = m
# err[i+1:] = dation
# accommodation
# --
# added tupple = ('m', 'm')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = accomodations
# Correction = accommodations
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = o
# err[i] = m
# corr[i] = m
# err[i] = o
# corr[i] = m
# --
# err[0:i] = accom
# corr[i] = m
# err[i+1:] = dations
# accommodations
# --
# added tupple = ('m', 'm')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = accompanyed
# Correction = accompanied
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = o
# err[i] = m
# corr[i] = m
# err[i] = p
# corr[i] = p
# err[i] = a
# corr[i] = a
# err[i] = n
# corr[i] = n
# err[i] = y
# corr[i] = i
# added tupple = ('i', 'n')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accordeon
# Correction = accordion
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = o
# err[i] = r
# corr[i] = r
# err[i] = d
# corr[i] = d
# err[i] = e
# corr[i] = i
# added tupple = ('i', 'd')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accordian
# Correction = accordion
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = o
# err[i] = r
# corr[i] = r
# err[i] = d
# corr[i] = d
# err[i] = i
# corr[i] = i
# err[i] = a
# corr[i] = o
# added tupple = ('o', 'i')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accoring
# Correction = according
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = o
# err[i] = r
# corr[i] = r
# err[i] = i
# corr[i] = d
# --
# err[0:i] = accor
# corr[i] = d
# err[i+1:] = ng
# according
# --
# added tupple = ('d', 'r')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accoustic
# Correction = acoustic
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = ccoustic
# current char = c
# first part = a
# second part = coustic
# added tupple = ('c', 'a')
# deletion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = accquainted
# Correction = acquainted
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = ccquainted
# current char = c
# first part = a
# second part = cquainted
# added tupple = ('c', 'a')
# deletion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = accrediation
# Correction = accreditation
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = r
# corr[i] = r
# err[i] = e
# corr[i] = e
# err[i] = d
# corr[i] = d
# err[i] = i
# corr[i] = i
# err[i] = a
# corr[i] = t
# --
# err[0:i] = accredi
# corr[i] = t
# err[i+1:] = tion
# accreditation
# --
# added tupple = ('t', 'i')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accredidation
# Correction = accreditation
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = c
# corr[i] = c
# err[i] = r
# corr[i] = r
# err[i] = e
# corr[i] = e
# err[i] = d
# corr[i] = d
# err[i] = i
# corr[i] = i
# err[i] = d
# corr[i] = t
# added tupple = ('t', 'i')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = accross
# Correction = across
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = ccross
# current char = c
# first part = a
# second part = cross
# added tupple = ('c', 'a')
# deletion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = accussed
# Correction = accused
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = ccussed
# current char = c
# first part = a
# second part = cussed
# current char = c
# first part = ac
# second part = ussed
# current char = u
# first part = acc
# second part = ssed
# current char = s
# first part = accu
# second part = sed
# added tupple = ('s', 'u')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = acedemic
# Correction = academic
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = e
# corr[i] = a
# added tupple = ('a', 'c')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = acheive
# Correction = achieve
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = e
# corr[i] = i
# added tupple = ('ei', 'ie')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = acheived
# Correction = achieved
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = e
# corr[i] = i
# added tupple = ('ei', 'ie')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acheivement
# Correction = achievement
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = e
# corr[i] = i
# added tupple = ('ei', 'ie')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acheivements
# Correction = achievements
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = e
# corr[i] = i
# added tupple = ('ei', 'ie')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acheives
# Correction = achieves
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = e
# corr[i] = i
# added tupple = ('ei', 'ie')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acheiving
# Correction = achieving
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = e
# corr[i] = i
# added tupple = ('ei', 'ie')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = achievment
# Correction = achievement
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = i
# corr[i] = i
# err[i] = e
# corr[i] = e
# err[i] = v
# corr[i] = v
# err[i] = m
# corr[i] = e
# --
# err[0:i] = achiev
# corr[i] = e
# err[i+1:] = ent
# achievement
# --
# added tupple = ('e', 'v')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = achievments
# Correction = achievements
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = i
# corr[i] = i
# err[i] = e
# corr[i] = e
# err[i] = v
# corr[i] = v
# err[i] = m
# corr[i] = e
# --
# err[0:i] = achiev
# corr[i] = e
# err[i+1:] = ents
# achievements
# --
# added tupple = ('e', 'v')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = achive
# Correction = achieve
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = i
# corr[i] = i
# err[i] = v
# corr[i] = e
# --
# err[0:i] = achi
# corr[i] = e
# err[i+1:] = e
# achieve
# --
# added tupple = ('e', 'i')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = achived
# Correction = achieved
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = i
# corr[i] = i
# err[i] = v
# corr[i] = e
# --
# err[0:i] = achi
# corr[i] = e
# err[i+1:] = ed
# achieved
# --
# added tupple = ('e', 'i')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = achivement
# Correction = achievement
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = i
# corr[i] = i
# err[i] = v
# corr[i] = e
# --
# err[0:i] = achi
# corr[i] = e
# err[i+1:] = ement
# achievement
# --
# added tupple = ('e', 'i')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = achivements
# Correction = achievements
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = i
# corr[i] = i
# err[i] = v
# corr[i] = e
# --
# err[0:i] = achi
# corr[i] = e
# err[i+1:] = ements
# achievements
# --
# added tupple = ('e', 'i')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acknowldeged
# Correction = acknowledged
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = k
# corr[i] = k
# err[i] = n
# corr[i] = n
# err[i] = o
# corr[i] = o
# err[i] = w
# corr[i] = w
# err[i] = l
# corr[i] = l
# err[i] = d
# corr[i] = e
# added tupple = ('de', 'ed')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = acknowledgeing
# Correction = acknowledging
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = cknowledgeing
# current char = c
# first part = a
# second part = knowledgeing
# current char = k
# first part = ac
# second part = nowledgeing
# current char = n
# first part = ack
# second part = owledgeing
# current char = o
# first part = ackn
# second part = wledgeing
# current char = w
# first part = ackno
# second part = ledgeing
# current char = l
# first part = acknow
# second part = edgeing
# current char = e
# first part = acknowl
# second part = dgeing
# current char = d
# first part = acknowle
# second part = geing
# current char = g
# first part = acknowled
# second part = eing
# current char = e
# first part = acknowledg
# second part = ing
# added tupple = ('e', 'g')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = ackward
# Correction = awkward
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = w
# added tupple = ('w', 'a')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = acommodate
# Correction = accommodate
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = c
# --
# err[0:i] = ac
# corr[i] = c
# err[i+1:] = mmodate
# accommodate
# --
# added tupple = ('c', 'c')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acomplish
# Correction = accomplish
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = c
# --
# err[0:i] = ac
# corr[i] = c
# err[i+1:] = mplish
# accomplish
# --
# added tupple = ('c', 'c')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acomplished
# Correction = accomplished
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = c
# --
# err[0:i] = ac
# corr[i] = c
# err[i+1:] = mplished
# accomplished
# --
# added tupple = ('c', 'c')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acomplishment
# Correction = accomplishment
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = c
# --
# err[0:i] = ac
# corr[i] = c
# err[i+1:] = mplishment
# accomplishment
# --
# added tupple = ('c', 'c')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acomplishments
# Correction = accomplishments
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = c
# --
# err[0:i] = ac
# corr[i] = c
# err[i+1:] = mplishments
# accomplishments
# --
# added tupple = ('c', 'c')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acording
# Correction = according
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = c
# --
# err[0:i] = ac
# corr[i] = c
# err[i+1:] = rding
# according
# --
# added tupple = ('c', 'c')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acordingly
# Correction = accordingly
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = o
# corr[i] = c
# --
# err[0:i] = ac
# corr[i] = c
# err[i+1:] = rdingly
# accordingly
# --
# added tupple = ('c', 'c')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acquaintence
# Correction = acquaintance
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = q
# corr[i] = q
# err[i] = u
# corr[i] = u
# err[i] = a
# corr[i] = a
# err[i] = i
# corr[i] = i
# err[i] = n
# corr[i] = n
# err[i] = t
# corr[i] = t
# err[i] = e
# corr[i] = a
# added tupple = ('a', 't')
# substitution_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acquaintences
# Correction = acquaintances
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = q
# corr[i] = q
# err[i] = u
# corr[i] = u
# err[i] = a
# corr[i] = a
# err[i] = i
# corr[i] = i
# err[i] = n
# corr[i] = n
# err[i] = t
# corr[i] = t
# err[i] = e
# corr[i] = a
# added tupple = ('a', 't')
# substitution_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acquited
# Correction = acquitted
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = q
# corr[i] = q
# err[i] = u
# corr[i] = u
# err[i] = i
# corr[i] = i
# err[i] = t
# corr[i] = t
# err[i] = e
# corr[i] = t
# --
# err[0:i] = acquit
# corr[i] = t
# err[i+1:] = d
# acquitted
# --
# added tupple = ('t', 't')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = activites
# Correction = activities
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = t
# corr[i] = t
# err[i] = i
# corr[i] = i
# err[i] = v
# corr[i] = v
# err[i] = i
# corr[i] = i
# err[i] = t
# corr[i] = t
# err[i] = e
# corr[i] = i
# --
# err[0:i] = activit
# corr[i] = i
# err[i+1:] = s
# activities
# --
# added tupple = ('i', 't')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = activly
# Correction = actively
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = t
# corr[i] = t
# err[i] = i
# corr[i] = i
# err[i] = v
# corr[i] = v
# err[i] = l
# corr[i] = e
# --
# err[0:i] = activ
# corr[i] = e
# err[i+1:] = y
# actively
# --
# added tupple = ('e', 'v')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = actualy
# Correction = actually
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = t
# corr[i] = t
# err[i] = u
# corr[i] = u
# err[i] = a
# corr[i] = a
# err[i] = l
# corr[i] = l
# err[i] = y
# corr[i] = l
# --
# err[0:i] = actual
# corr[i] = l
# err[i+1:] =
# actually
# --
# added tupple = ('l', 'l')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acuracy
# Correction = accuracy
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = u
# corr[i] = c
# --
# err[0:i] = ac
# corr[i] = c
# err[i+1:] = racy
# accuracy
# --
# added tupple = ('c', 'c')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acused
# Correction = accused
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = u
# corr[i] = c
# --
# err[0:i] = ac
# corr[i] = c
# err[i+1:] = sed
# accused
# --
# added tupple = ('c', 'c')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = acustom
# Correction = accustom
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = u
# corr[i] = c
# --
# err[0:i] = ac
# corr[i] = c
# err[i+1:] = stom
# accustom
# --
# added tupple = ('c', 'c')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = adavanced
# Correction = advanced
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = davanced
# current char = d
# first part = a
# second part = avanced
# current char = a
# first part = ad
# second part = vanced
# added tupple = ('a', 'd')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = adbandon
# Correction = abandon
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = dbandon
# current char = d
# first part = a
# second part = bandon
# added tupple = ('d', 'a')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = additinally
# Correction = additionally
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = d
# corr[i] = d
# err[i] = i
# corr[i] = i
# err[i] = t
# corr[i] = t
# err[i] = i
# corr[i] = i
# err[i] = n
# corr[i] = o
# --
# err[0:i] = additi
# corr[i] = o
# err[i+1:] = ally
# additionally
# --
# added tupple = ('o', 'i')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = additionaly
# Correction = additionally
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = d
# corr[i] = d
# err[i] = i
# corr[i] = i
# err[i] = t
# corr[i] = t
# err[i] = i
# corr[i] = i
# err[i] = o
# corr[i] = o
# err[i] = n
# corr[i] = n
# err[i] = a
# corr[i] = a
# err[i] = l
# corr[i] = l
# err[i] = y
# corr[i] = l
# --
# err[0:i] = additional
# corr[i] = l
# err[i+1:] =
# additionally
# --
# added tupple = ('l', 'l')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = additonal
# Correction = additional
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = d
# corr[i] = d
# err[i] = i
# corr[i] = i
# err[i] = t
# corr[i] = t
# err[i] = o
# corr[i] = i
# --
# err[0:i] = addit
# corr[i] = i
# err[i+1:] = nal
# additional
# --
# added tupple = ('i', 't')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = additonally
# Correction = additionally
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = d
# corr[i] = d
# err[i] = i
# corr[i] = i
# err[i] = t
# corr[i] = t
# err[i] = o
# corr[i] = i
# --
# err[0:i] = addit
# corr[i] = i
# err[i+1:] = nally
# additionally
# --
# added tupple = ('i', 't')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = addmission
# Correction = admission
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = ddmission
# current char = d
# first part = a
# second part = dmission
# added tupple = ('d', 'a')
# deletion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = addopt
# Correction = adopt
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = ddopt
# current char = d
# first part = a
# second part = dopt
# added tupple = ('d', 'a')
# deletion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = addopted
# Correction = adopted
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = ddopted
# current char = d
# first part = a
# second part = dopted
# added tupple = ('d', 'a')
# deletion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = addoptive
# Correction = adoptive
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = ddoptive
# current char = d
# first part = a
# second part = doptive
# added tupple = ('d', 'a')
# deletion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = addres
# Correction = address
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = d
# corr[i] = d
# err[i] = r
# corr[i] = r
# err[i] = e
# corr[i] = e
# err[i] = s
# corr[i] = s
# -------------------
# -------------------
# Error = addresable
# Correction = addressable
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = d
# corr[i] = d
# err[i] = r
# corr[i] = r
# err[i] = e
# corr[i] = e
# err[i] = s
# corr[i] = s
# err[i] = a
# corr[i] = s
# --
# err[0:i] = addres
# corr[i] = s
# err[i+1:] = ble
# addressable
# --
# added tupple = ('s', 's')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = addresed
# Correction = addressed
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = d
# corr[i] = d
# err[i] = r
# corr[i] = r
# err[i] = e
# corr[i] = e
# err[i] = s
# corr[i] = s
# err[i] = e
# corr[i] = s
# --
# err[0:i] = addres
# corr[i] = s
# err[i+1:] = d
# addressed
# --
# added tupple = ('s', 's')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = addresing
# Correction = addressing
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = d
# corr[i] = d
# err[i] = r
# corr[i] = r
# err[i] = e
# corr[i] = e
# err[i] = s
# corr[i] = s
# err[i] = i
# corr[i] = s
# --
# err[0:i] = addres
# corr[i] = s
# err[i+1:] = ng
# addressing
# --
# added tupple = ('s', 's')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = addressess
# Correction = addresses
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = ddressess
# current char = d
# first part = a
# second part = dressess
# current char = d
# first part = ad
# second part = ressess
# current char = r
# first part = add
# second part = essess
# current char = e
# first part = addr
# second part = ssess
# current char = s
# first part = addre
# second part = sess
# current char = s
# first part = addres
# second part = ess
# current char = e
# first part = address
# second part = ss
# current char = s
# first part = addresse
# second part = s
# added tupple = ('s', 'e')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = addtion
# Correction = addition
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = d
# corr[i] = d
# err[i] = t
# corr[i] = i
# --
# err[0:i] = add
# corr[i] = i
# err[i+1:] = ion
# addition
# --
# added tupple = ('i', 'd')
# insertion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = addtional
# Correction = additional
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = d
# corr[i] = d
# err[i] = t
# corr[i] = i
# --
# err[0:i] = add
# corr[i] = i
# err[i+1:] = ional
# additional
# --
# added tupple = ('i', 'd')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = adecuate
# Correction = adequate
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = e
# corr[i] = e
# err[i] = c
# corr[i] = q
# added tupple = ('q', 'e')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = adhearing
# Correction = adhering
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = dhearing
# current char = d
# first part = a
# second part = hearing
# current char = h
# first part = ad
# second part = earing
# current char = e
# first part = adh
# second part = aring
# current char = a
# first part = adhe
# second part = ring
# added tupple = ('a', 'e')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = adherance
# Correction = adherence
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = h
# corr[i] = h
# err[i] = e
# corr[i] = e
# err[i] = r
# corr[i] = r
# err[i] = a
# corr[i] = e
# added tupple = ('e', 'r')
# substitution_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = admendment
# Correction = amendment
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = a
# first part =
# second part = dmendment
# current char = d
# first part = a
# second part = mendment
# added tupple = ('d', 'a')
# deletion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = adminstered
# Correction = administered
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = a
# corr[i] = a
# err[i] = d
# corr[i] = d
# err[i] = m
# corr[i] = m
# err[i] = i
# corr[i] = i
# err[i] = n
# ...
# err[i] = w
# corr[i] = w
# err[i] = r
# corr[i] = r
# err[i] = i
# corr[i] = i
# err[i] = e
# corr[i] = t
# -------------------
# -------------------
# Error = writen
# Correction = written
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = w
# corr[i] = w
# err[i] = r
# corr[i] = r
# err[i] = i
# corr[i] = i
# err[i] = t
# corr[i] = t
# err[i] = e
# corr[i] = t
# --
# err[0:i] = writ
# corr[i] = t
# err[i+1:] = n
# written
# --
# added tupple = ('t', 't')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = wroet
# Correction = wrote
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = w
# corr[i] = w
# err[i] = r
# corr[i] = r
# err[i] = o
# corr[i] = o
# err[i] = e
# corr[i] = t
# -------------------
# -------------------
# Error = wrok
# Correction = work
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = w
# corr[i] = w
# err[i] = r
# corr[i] = o
# added tupple = ('ro', 'or')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = wroking
# Correction = working
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = w
# corr[i] = w
# err[i] = r
# corr[i] = o
# added tupple = ('ro', 'or')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = wtih
# Correction = with
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = w
# corr[i] = w
# err[i] = t
# corr[i] = i
# added tupple = ('ti', 'it')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = wupport
# Correction = support
# return_inserts = False
# return_deletes = False
# return_transposes = False
# return_replaces = True
# err[i] = w
# corr[i] = s
# added tupple = ('s', 't')
# substitution_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = yaching
# Correction = yachting
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = y
# corr[i] = y
# err[i] = a
# corr[i] = a
# err[i] = c
# corr[i] = c
# err[i] = h
# corr[i] = h
# err[i] = i
# corr[i] = t
# --
# err[0:i] = yach
# corr[i] = t
# err[i+1:] = ng
# yachting
# --
# added tupple = ('t', 'h')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = yaer
# Correction = year
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = y
# corr[i] = y
# err[i] = a
# corr[i] = e
# added tupple = ('ae', 'ea')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = yaerly
# Correction = yearly
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = y
# corr[i] = y
# err[i] = a
# corr[i] = e
# added tupple = ('ae', 'ea')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = yaers
# Correction = years
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = y
# corr[i] = y
# err[i] = a
# corr[i] = e
# added tupple = ('ae', 'ea')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = yearm
# Correction = year
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = y
# first part =
# second part = earm
# current char = e
# first part = y
# second part = arm
# current char = a
# first part = ye
# second part = rm
# current char = r
# first part = yea
# second part = m
# current char = m
# first part = year
# second part =
# added tupple = ('m', 'r')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = yeasr
# Correction = years
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = y
# corr[i] = y
# err[i] = e
# corr[i] = e
# err[i] = a
# corr[i] = a
# err[i] = s
# corr[i] = r
# -------------------
# -------------------
# Error = yeild
# Correction = yield
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = y
# corr[i] = y
# err[i] = e
# corr[i] = i
# added tupple = ('ei', 'ie')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = yeilding
# Correction = yielding
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = y
# corr[i] = y
# err[i] = e
# corr[i] = i
# added tupple = ('ei', 'ie')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = Yementite
# Correction = Yemenite
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = Y
# first part =
# second part = ementite
# current char = e
# first part = Y
# second part = mentite
# current char = m
# first part = Ye
# second part = entite
# current char = e
# first part = Yem
# second part = ntite
# current char = n
# first part = Yeme
# second part = tite
# current char = t
# first part = Yemen
# second part = ite
# added tupple = ('t', 'n')
# deletion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = yera
# Correction = year
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = y
# corr[i] = y
# err[i] = e
# corr[i] = e
# err[i] = r
# corr[i] = a
# -------------------
# -------------------
# Error = yeras
# Correction = years
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = y
# corr[i] = y
# err[i] = e
# corr[i] = e
# err[i] = r
# corr[i] = a
# added tupple = ('ra', 'ar')
# transposition_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = yotube
# Correction = youtube
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = y
# corr[i] = y
# err[i] = o
# corr[i] = o
# err[i] = t
# corr[i] = u
# --
# err[0:i] = yo
# corr[i] = u
# err[i+1:] = ube
# youtube
# --
# added tupple = ('u', 'o')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = youseff
# Correction = yousef
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = y
# first part =
# second part = ouseff
# current char = o
# first part = y
# second part = useff
# current char = u
# first part = yo
# second part = seff
# current char = s
# first part = you
# second part = eff
# current char = e
# first part = yous
# second part = ff
# current char = f
# first part = youse
# second part = f
# added tupple = ('f', 'e')
# deletion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = youself
# Correction = yourself
# return_inserts = True
# return_deletes = False
# return_transposes = False
# return_replaces = False
# err[i] = y
# corr[i] = y
# err[i] = o
# corr[i] = o
# err[i] = u
# corr[i] = u
# err[i] = s
# corr[i] = r
# --
# err[0:i] = you
# corr[i] = r
# err[i+1:] = elf
# yourself
# --
# added tupple = ('r', 'u')
# insertion_dict is not empty. adding 1 to it's value
# -------------------
# -------------------
# Error = ytou
# Correction = you
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = y
# first part =
# second part = tou
# current char = t
# first part = y
# second part = ou
# added tupple = ('t', 'y')
# deletion_dict is empty. default value is 1 now
# -------------------
# -------------------
# Error = yuo
# Correction = you
# return_inserts = False
# return_deletes = False
# return_transposes = True
# return_replaces = False
# err[i] = y
# corr[i] = y
# err[i] = u
# corr[i] = o
# -------------------
# -------------------
# Error = zeebra
# Correction = zebra
# return_inserts = False
# return_deletes = True
# return_transposes = False
# return_replaces = False
# current char = z
# first part =
# second part = eebra
# current char = e
# first part = z
# second part = ebra
# added tupple = ('e', 'z')
# deletion_dict is empty. default value is 1 now
# -------------------
# {'deletion': {('n', 'o'): 7, ('b', 'a'): 1, ('c', 's'): 7, ('i', 'c'): 5, ('t', 'u'): 2, ('c', 'a'): 6, ('l', 'e'): 8, ('s', 'u'): 4, ('e', 'g'): 4, ('a', 'd'): 4, ('d', 'a'): 9, ('s', 'e'): 12, ('a', 'e'): 10, ('f', 'a'): 2, ('l', 'i'): 19, ('n', 'i'): 12, ('a', 'g'): 1, ('g', 'a'): 2, ('e', 'r'): 17, ('u', 'o'): 17, ('s', 't'): 1, ('r', 'i'): 2, ('i', 'a'): 8, ('h', 'c'): 9, ('t', 'n'): 5, ('d', 'e'): 9, ('e', 'd'): 8, ('l', 'a'): 11, ('t', 'o'): 2, ('t', 'h'): 3, ('r', 'e'): 20, ('m', 'a'): 7, ('t', 's'): 5, ('b', 'n'): 1, ('o', 't'): 1, ('i', 'l'): 17, ('d', 'n'): 2, ('n', 'a'): 14, ('p', 'a'): 5, ('r', 'p'): 5, ('i', 'r'): 13, ('c', 'i'): 3, ('e', 'u'): 6, ('r', 'a'): 17, ('s', 'a'): 10, ('r', 't'): 5, ('t', 'a'): 9, ('h', 't'): 10, ('r', 'h'): 3, ('a', 'm'): 2, ('c', 'e'): 12, ('e', 'm'): 7, ('m', 'o'): 8, ('e', 'b'): 4, ('g', 